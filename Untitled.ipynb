# %%
import requests
ID = 49313208
YEAR = 2020
url = f"https://fantasy.espn.com/apis/v3/games/ffl/seasons/{YEAR}/segments/0/leagues/{ID}"

r = requests.get(url)
# d = r.json()[0]

print(r.json())
# Out:
# {'gameId': 1, 'id': 49313208, 'members': [{'displayName': 'espn96848591', 'id': '{0505D37E-508F-4BCA-AAEE-46682BB5758A}', 'isLeagueManager': False}, {'displayName': 'sumantisbeast', 'id': '{0A16FA3C-7066-4C31-8EFD-9A1B41CC28F7}', 'isLeagueManager': False}, {'displayName': 'ESPNfan19511080', 'id': '{3B8BC9AF-11B3-4292-89C5-1C1C21CB9E8F}', 'isLeagueManager': False}, {'displayName': 'espn06221196', 'id': '{74C2EBBF-0B81-4E43-9CD1-B7A082B34F84}', 'isLeagueManager': False}, {'displayName': 'espn00973543', 'id': '{74CFF96F-5857-4231-85D7-CD6AA488CD10}', 'isLeagueManager': False}, {'displayName': 'ESPNfan0884446169', 'id': '{AB767E42-231C-41F2-8DDD-C9B5D03187E7}', 'isLeagueManager': False}, {'displayName': 'ESPNFAN2895745117', 'id': '{D7B2BCC7-E508-4FF9-BBF8-5234BBA635FF}', 'isLeagueManager': False}, {'displayName': 'ESPNFAN34032972', 'id': '{F40ECFF3-F69D-4BF4-9EC6-08AD38BD5677}', 'isLeagueManager': False}], 'scoringPeriodId': 0, 'seasonId': 2020, 'segmentId': 0, 'settings': {'name': 'Tru 
# ...

# %%
#https://fantasy.espn.com/football/leaders?leagueId=49313208&lineupSlot=2&scoringPeriodId=0&statSplit=lastSeason

week = 0

# url = f"https://fantasy.espn.com/apis/v3/games/ffl/seasons/{YEAR}/segments/0/leagues/{ID}" + "?view=mMatchup&view=mMatchupScore"
url = "https://fantasy.espn.com/football/leaders?leagueId=49313208&lineupSlot=2&scoringPeriodId=0&statSplit=lastSeason"
# r = requests.get(url,params={'scoringPeriodId': week})
r = requests.get(url)
r.cookies
# Out:
# <RequestsCookieJar[Cookie(version=0, name='_dcf', value='1', port=None, port_specified=False, domain='fantasy.espn.com', domain_specified=False, domain_initial_dot=False, path='/', path_specified=True, secure=False, expires=1599430440, discard=False, comment=None, comment_url=None, rest={}, rfc2109=False), Cookie(version=0, name='region', value='unknown', port=None, port_specified=False, domain='fantasy.espn.com', domain_specified=False, domain_initial_dot=False, path='/', path_specified=True, secure=False, expires=1599430440, discard=False, comment=None, comment_url=None, rest={}, rfc2109=False)]>

# %%
a.json()
# Out:
# {'draftDetail': {'completeDate': 1571019145991,
#   'drafted': True,
#   'inProgress': False},
#  'gameId': 3,
#  'id': 40021897,
#  'members': [{'displayName': 'Armghan123',
#    'firstName': 'Armghan',
#    'id': '{04720B0C-98CA-4BEE-B20B-0C98CABBEEB2}',
#    'isLeagueCreator': False,
#    'isLeagueManager': False,
#    'lastName': 'Mirza',
#    'notificationSettings': [{'enabled': True,
#      'id': 'c95c9f1b-2417-429a-902d-8978268e56ae',
#      'type': 'TEAM_TRADE_OFFER'},
#     {'enabled': True,
#      'id': '2b07393c-be52-4281-8d7b-7dd418a41073',
#      'type': 'TEAM_PLAYER_NEWS'},
#     {'enabled': True,
#      'id': '580c8e94-6dcb-455c-a22c-120d5ab9ed47',
#      'type': 'DRAFT'},
#     {'enabled': True,
#      'id': '00a13aab-ba44-4357-b192-5ccec963f7cc',
#      'type': 'TEAM_PLAYER_AVAILABILITY'}]},
#   {'displayName': 'espn96848591',
#    'firstName': 'Kevin',
#    'id': '{0505D37E-508F-4BCA-AAEE-46682BB5758A}',
#    'isLeagueCreator': False,
#    'isLeagueManager': False,
# ...

# %%
url = f"http://fantasy.espn.com/apis/v3/games/fba/seasons/{year}/segments/0/leagues/{LEAGUE_ID}"
a = requests.get(url)
a
# Out:
# <Response [200]>

# %%
a.json()
# Out:
# {'gameId': 3,
#  'id': 40021897,
#  'members': [{'displayName': 'Armghan123',
#    'id': '{04720B0C-98CA-4BEE-B20B-0C98CABBEEB2}',
#    'isLeagueManager': False},
#   {'displayName': 'espn96848591',
#    'id': '{0505D37E-508F-4BCA-AAEE-46682BB5758A}',
#    'isLeagueManager': False},
#   {'displayName': 'sumantisbeast',
#    'id': '{0A16FA3C-7066-4C31-8EFD-9A1B41CC28F7}',
#    'isLeagueManager': False},
#   {'displayName': 'ESPNfan19511080',
#    'id': '{3B8BC9AF-11B3-4292-89C5-1C1C21CB9E8F}',
#    'isLeagueManager': False},
#   {'displayName': 'venkymaster',
#    'id': '{49351784-07D1-4A1B-9450-04F4DDC7AB02}',
#    'isLeagueManager': False},
#   {'displayName': 'espn06221196',
#    'id': '{74C2EBBF-0B81-4E43-9CD1-B7A082B34F84}',
#    'isLeagueManager': False},
#   {'displayName': 'espn00973543',
#    'id': '{74CFF96F-5857-4231-85D7-CD6AA488CD10}',
#    'isLeagueManager': False},
#   {'displayName': 'ESPNFAN4540852061',
#    'id': '{936C0553-8FFD-45A3-B259-7EB9D072DF90}',
# ...
